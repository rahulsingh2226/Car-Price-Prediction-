# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/Car details v3.csv')
df.head()
# Out:
#                            name  year  Selling Price  Km driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller type transmission         owner     mileage   engine   max power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df.shape
# Out:
# (8128, 13)

# %%
def car():
  df = pd.read_csv('/content/Car details v3.csv')

  print('\n---Head---')
  print(df.head())

  print('\n---Shape---')
  print(df.shape)

  print('\n---Info---')
  print(df.info())

  print('\n---Describe---')
  print(df.describe())

  print('\n---Null Values---')
  print(df.isnull().sum())

car()
# Out:
# ---Head---
#                            name  year  Selling Price  Km driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller type transmission         owner     mileage   engine   max power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df.columns
# Out:
# Index(['name', 'year', 'Selling Price', 'Km driven', 'fuel', 'seller type',
#        'transmission', 'owner', 'mileage', 'engine', 'max power', 'torque',
#        'seats'],
#       dtype='object')

# %%
a = []
for i in df:
  a.append(i.lower().replace(' ', '_'))
a
# Out:
# ['name',
#  'year',
#  'selling_price',
#  'km_driven',
#  'fuel',
#  'seller_type',
#  'transmission',
#  'owner',
#  'mileage',
#  'engine',
#  'max_power',
#  'torque',
#  'seats']

# %%
df.columns=a
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df.drop(columns=['torque'], inplace=True)
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'seats'],
#       dtype='object')

# %%
num_cols = df.select_dtypes(include=[float,int]).columns
num_cols
# Out:
# Index(['year', 'selling_price', 'km_driven', 'seats'], dtype='object')

# %%
for i in num_cols:
  plt.figure(figsize=(5,3)),
  sns.boxplot(x=df[i])

# %%
for i in num_cols:
  plt.figure(figsize=(5,3))
  sns.histplot(x=df[i], kde=True)

# %%
sns.heatmap(df[num_cols].corr(),annot=True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#    seats
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0

# %%
df['mileage']=df['mileage'].str.replace('kmpl','')
df['engine']=df['engine'].str.replace('CC','')
df['max_power']=df['max_power'].str.replace('bhp','')
df['mileage']=df['mileage'].str.replace('km/kg','')

# %%
df['name'].value_counts()
# Out:
# name
# Maruti Swift Dzire VDI              129
# Maruti Alto 800 LXI                  82
# Maruti Alto LXi                      71
# BMW X4 M Sport X xDrive20d           62
# Maruti Swift VDI                     61
#                                    ...
# Maruti 800 DX BSII                    1
# Ford Figo Aspire Titanium Diesel      1
# Hyundai Verna CRDi 1.6 SX             1
# Maruti Baleno Alpha Diesel            1
# Tata New Safari Dicor VX 4X2          1
# Name: count, Length: 2058, dtype: int64

# %%
df.name = df['name'].str.split(' ').str[0]

# %%
df.name
# Out:
# 0        Maruti
# 1         Skoda
# 2         Honda
# 3       Hyundai
# 4        Maruti
#          ...
# 8123    Hyundai
# 8124    Hyundai
# 8125     Maruti
# 8126       Tata
# 8127       Tata
# Name: name, Length: 8128, dtype: object

# %%
df.head()
# Out:
#       name  year  selling_price  km_driven    fuel seller_type transmission  \
# 0   Maruti  2014         450000     145500  Diesel  Individual       Manual
# 1    Skoda  2014         370000     120000  Diesel  Individual       Manual
# 2    Honda  2006         158000     140000  Petrol  Individual       Manual
# 3  Hyundai  2010         225000     127000  Diesel  Individual       Manual
# 4   Maruti  2007         130000     120000  Petrol  Individual       Manual
#
#           owner mileage engine max_power  seats
# 0   First Owner   23.4   1248        74     5.0
# 1  Second Owner  21.14   1498    103.52     5.0
# 2   Third Owner   17.7   1497        78     5.0
# 3   First Owner   23.0   1396        90     5.0
# 4   First Owner   16.1   1298      88.2     5.0

# %%
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
encoder= LabelEncoder()
Ordinal = OrdinalEncoder()
df['name'] = encoder.fit_transform(df['name'])
df['transmission'] = encoder.fit_transform(df['transmission'])
df['fuel'] = encoder.fit_transform(df['fuel'])
df['seller_type'] = encoder.fit_transform(df['seller_type'])

# %%
Owner_enc = OrdinalEncoder(categories=[['Test Drive Car','Fourth & Above Owner', 'Third Owner','Second Owner','First Owner']])
df['Encoded'] = Owner_enc.fit_transform(df[['owner']])

# %%
#ordinal encoding in years since it has hierarchy
# sorting years in order since larget data set with too many years to type
#used help with this code
sorted_years=sorted(df['year'].unique())
year_order = [[year] for year in sorted_years]

encoder = OrdinalEncoder(categories=[sorted_years])
df['year_encoded'] = encoder.fit_transform(df[['year']])
print(df['year_encoded'])
# Out:
# 0       22.0
# 1       22.0
# 2       14.0
# 3       18.0
# 4       15.0
#         ...
# 8123    21.0
# 8124    15.0
# 8125    17.0
# 8126    21.0
# 8127    21.0
# Name: year_encoded, Length: 8128, dtype: float64

# %%
df.head()
# Out:
#    name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 0    20  2014         450000     145500     1            1             1
# 1    27  2014         370000     120000     1            1             1
# 2    10  2006         158000     140000     3            1             1
# 3    11  2010         225000     127000     1            1             1
# 4    20  2007         130000     120000     3            1             1
#
#           owner mileage engine max_power  seats  Encoded  year_encoded
# 0   First Owner   23.4   1248        74     5.0      4.0          22.0
# 1  Second Owner  21.14   1498    103.52     5.0      3.0          22.0
# 2   Third Owner   17.7   1497        78     5.0      2.0          14.0
# 3   First Owner   23.0   1396        90     5.0      4.0          18.0
# 4   First Owner   16.1   1298      88.2     5.0      4.0          15.0

# %%
plt.figure(figsize=(5,3))
sns.histplot(x=df['selling_price'])

#output column we can do transformatiom
# Out:
# <Axes: xlabel='selling_price', ylabel='Count'>

# %%
df.year.duplicated().sum()
# Out:
# np.int64(8099)

# %%
df.drop(columns=['year'], inplace=True)

# %%
df.head()
# Out:
#    name  selling_price  km_driven  fuel  seller_type  transmission  \
# 0    20         450000     145500     1            1             1
# 1    27         370000     120000     1            1             1
# 2    10         158000     140000     3            1             1
# 3    11         225000     127000     1            1             1
# 4    20         130000     120000     3            1             1
#
#           owner mileage engine max_power  seats  Encoded  year_encoded
# 0   First Owner   23.4   1248        74     5.0      4.0          22.0
# 1  Second Owner  21.14   1498    103.52     5.0      3.0          22.0
# 2   Third Owner   17.7   1497        78     5.0      2.0          14.0
# 3   First Owner   23.0   1396        90     5.0      4.0          18.0
# 4   First Owner   16.1   1298      88.2     5.0      4.0          15.0

# %%
df.drop(columns=['owner'], inplace=True)

# %%
df.head()
# Out:
#    name  selling_price  km_driven  fuel  seller_type  transmission mileage  \
# 0    20         450000     145500     1            1             1   23.4
# 1    27         370000     120000     1            1             1  21.14
# 2    10         158000     140000     3            1             1   17.7
# 3    11         225000     127000     1            1             1   23.0
# 4    20         130000     120000     3            1             1   16.1
#
#   engine max_power  seats  Encoded  year_encoded
# 0  1248        74     5.0      4.0          22.0
# 1  1498    103.52     5.0      3.0          22.0
# 2  1497        78     5.0      2.0          14.0
# 3  1396        90     5.0      4.0          18.0
# 4  1298      88.2     5.0      4.0          15.0

# %%
X = df.drop(columns=['selling_price'])
Y = df['selling_price']

# %%
X
# Out:
#       name  km_driven  fuel  seller_type  transmission mileage engine  \
# 0       20     145500     1            1             1   23.4   1248
# 1       27     120000     1            1             1  21.14   1498
# 2       10     140000     3            1             1   17.7   1497
# 3       11     127000     1            1             1   23.0   1396
# 4       20     120000     3            1             1   16.1   1298
# ...    ...        ...   ...          ...           ...     ...    ...
# 8123    11     110000     3            1             1   18.5   1197
# 8124    11     119000     1            1             1   16.8   1493
# 8125    20     120000     1            1             1   19.3   1248
# 8126    28      25000     1            1             1  23.57   1396
# 8127    28      25000     1            1             1  23.57   1396
#
#      max_power  seats  Encoded  year_encoded
# 0          74     5.0      4.0          22.0
# 1      103.52     5.0      3.0          22.0
# ...

# %%
# checking datatype of each column
# here mileage, engine and max_power are object type

# df.info()

# %%
# converting the datatype of mileage and engine to float

# df['mileage'] = df['mileage'].astype(float)
# df['engine'] = df['engine'].astype(float)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-29c2e9c45729> in <cell line: 0>()
# ----> 1 X_train_scaled = scaler.fit_transform(X_train)
#       2 X_test_scaled = scaler.transform(X_test)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     916         if y is None:
#     917             # fit method of arity 1 (unsupervised transformation)
# --> 918             return self.fit(X, **fit_params).transform(X)
#     919         else:
# ...

# %%
#took help to correct above error. We can discuss on monday about this. There were Nan values in data.
#We can discuss how to go about that in class.

for col in X_train.select_dtypes(include=['object']).columns:
    X_train[col] = pd.to_numeric(X_train[col], errors='coerce')
    X_test[col] = pd.to_numeric(X_test[col], errors='coerce')

# Impute NaN values with 0 (or any other suitable strategy)
X_train = X_train.fillna(0)  # Replace NaN with 0 or choose your method
X_test = X_test.fillna(0)

# Now apply scaling
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
Y_train_log = np.log1p(Y_train)
Y_test_log = np.log1p(Y_test)
#logarthimic transformation on output column. Increases performance.
#can be applied to input also if data has skewness
# helps to get normal distribution.
# np.sqrt(Y_train) is squareroot transformation code/can be used instead of logarthmic

# %%
plt.figure(figsize=(5,3))
sns.histplot(x=Y_train_log)
# Out:
# <Axes: xlabel='selling_price', ylabel='Count'>

# %%
# in many cases during course we used model.fit(X_train instead of scaled version which is X_Train_Scaled)
# we can discuss in class why X train and not scaled model to be used in model.
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,Y_train_log)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
Y_test
# Out:
# 1971    198000
# 4664    500000
# 5448    425000
# 3333    150000
# 2316    525000
#          ...
# 462     600000
# 1956    400000
# 3782    500000
# 799     400000
# 2402    425000
# Name: selling_price, Length: 2439, dtype: int64

# %%
y_pred
# Out:
# array([11.74156289, 13.5869773 , 13.12444286, ..., 13.07952926,
#        12.97999636, 12.19895926])

# %%
model.coef_
# Out:
# array([-1.29753913e-03, -2.44832216e-07, -1.43146019e-01, -6.53778671e-02,
#        -2.31192908e-01, -2.05815897e-02,  1.58629820e-04,  8.66335013e-03,
#        -6.13596145e-02,  6.05416096e-02,  1.21447213e-01])

# %%
from sklearn.metrics import r2_score, mean_squared_error,mean_absolute_error

# %%
mse = mean_squared_error(Y_test_log,y_pred)
mse
# Out:
# 0.10174881576870015

# %%
rmse = np.sqrt(mse)
print(f"RMSE: {rmse:.2f}")
# Out:
# RMSE: 0.32

# %%
r2_score(Y_test_log,y_pred)
# Out:
# 0.8552705090050057

# %%
def plotGraph(Y_test,y_pred,regressorName):
    if max(Y_test) >= max(y_pred):
        my_range = int(max(Y_test))
    else:
        my_range = int(max(y_pred))
    plt.scatter(range(len(Y_test)), Y_test, color='blue')
    plt.scatter(range(len(y_pred)), y_pred, color='red')
    plt.title(regressorName)
    plt.show()
    return


y_test = range(10)
y_pred = np.random.randint(0, 10, 10)

plotGraph(Y_test, y_pred, "test")

# %%
print(len(Y_test))
print(y_pred.shape)
# Out:
# 2439
# (10,)
